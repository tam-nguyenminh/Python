# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
path = 'C:/Users/84393/OneDrive - CÔNG TY TNHH OFFICIENCE/PYTHON/Gradient_Descent/'
df = pd.read_csv(path + 'test_scores.csv')
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.00002
    cost_prev = 0

    for i in range(iterations):
        # if math.isclose(cost, cost_prev)
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        if math.isclose(cost_prev, cost, abs_tol = 1e-05) == True:
            break
        cost_prev = cost
        print("m {}, b {}, cost {}, iterations {}".format(m_curr, b_curr, cost, i))

X = df.math
y = df.cs
gradient_descent(X, y)
# Out:
# m 0.19783600000000004, b 0.0027960000000000003, cost 5199.1, iterations 0
# m 0.358202304128, b 0.005063270368, cost 3427.1133014146017, iterations 1
# m 0.48819558675989866, b 0.006901951280555265, cost 2262.7832239523723, iterations 2
# m 0.5935684284372227, b 0.008393216594681594, cost 1497.729778255618, iterations 3
# m 0.6789838841536092, b 0.009602866025233548, cost 995.0314573648972, iterations 4
# m 0.7482218369922624, b 0.010584236972134094, cost 664.7204139555688, iterations 5
# m 0.804346268858218, b 0.011380564854211883, cost 447.6809274080213, iterations 6
# m 0.8498408505179355, b 0.012026896401228556, cost 305.0694716371467, iterations 7
# m 0.8867188511966752, b 0.012551640572788583, cost 211.36289471465685, iterations 8
# m 0.9166122315504622, b 0.012977825736768155, cost 149.79054397304932, iterations 9
# m 0.940843862633698, b 0.01332411874103585, cost 109.33282466617912, iterations 10
# ...

# %%
print(math.isclose(8.005, 8.450, abs_tol = 0.4))
print(math.isclose(31.802547647469325, 31.8025485567692,  abs_tol = 1e-20))
# Out:
# False
# False

# %%
31.811828938505045-31.81184088456126
# Out:
# -1.1946056215350609e-05

# %%
from sklearn import linear_model

# %%
X = df.math
y = df.cs

# %%
X_reshaped = X.values.reshape(-1,1)
y_reshaped = y.values.reshape(-1,1)

# %%
reg = linear_model.LinearRegression()

reg.fit(X_reshaped,y_reshaped)
# Out:
# LinearRegression()

# %%
reg_m = reg.coef_
reg_m
# Out:
# array([[1.01773624]])

# %%
reg_b = reg.intercept_
reg_b
# Out:
# array([1.91521931])

# %%
m, b = gradient_descent(X,y)
print("Using gradient descent function: Coef {} Intercept {}".format(m, b))
# Out:
# m 0.0049459000000000005, b 6.99e-05, cost 5199.1, iterations 0
# m 0.009868381440080001, b 0.00013946954398000002, cost 5150.282223314384, iterations 1
# m 0.014767555205777124, b 0.0002087101966302587, cost 5101.925650891001, iterations 2
# m 0.01964353165759184, b 0.0002776235152323162, cost 5054.025925518484, iterations 3
# m 0.024496420633473983, b 0.0003462110496940738, cost 5006.578731150064, iterations 4
# m 0.029326331451296997, b 0.00041447434258470807, cost 4959.579792514682, iterations 5
# m 0.03413337291132047, b 0.00048241492916941884, cost 4913.024874731748, iterations 6
# m 0.03891765329864101, b 0.0005500343374440134, cost 4866.90978292957, iterations 7
# m 0.04367928038563151, b 0.0006173340881693267, cost 4821.2303618673495, iterations 8
# m 0.04841836143436884, b 0.0006843156949054784, cost 4775.982495560793, iterations 9
# m 0.05313500319905012, b 0.0007509806640459677, cost 4731.162106911221, iterations 10
# ...
